# %% [markdown]
# <a href="https://colab.research.google.com/github/KETI-saisc/new/blob/main/Siamese_networks_medium_5in_20_bright_ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # One Shot Learning with Siamese Networks
#
# This is the jupyter notebook that accompanies

# %% [markdown]
# ## Imports
# All the imports are defined here

# %%
# !python -V
# Out:
# Python 3.9.16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import os
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip list

# %% [markdown]
# ## Helper functions
# Set of helper functions

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()    

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %% [markdown]
# ## Configuration Class
# A simple class to manage configuration

# %%
class Config():
    training_dir = "/content/drive/My Drive/Colab Notebooks/data/5in_20_bright/training"
    testing_dir = "/content/drive/My Drive/Colab Notebooks/data/5in_20_bright/testing"
    # training_dir = "data/faces/training"
    # testing_dir = "data/faces/testing"
    train_batch_size = 64
    train_number_epochs = 400

# %% [markdown]
# ## Custom Dataset Class
# This dataset generates a pair of images. 0 for geniune pair and 1 for imposter pair

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self,imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                
                img1_tuple = random.choice(self.imageFolderDataset.imgs) 
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
# os.getcwd()

# %% [markdown]
# ## Using Image Folder Dataset

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)

# %%
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %% [markdown]
# ## Visualising some of the data
# The top row and the bottom row of any column is one pair. The 0s and 1s correspond to the column of the image.
# 1 indiciates dissimilar, and 0 indicates similar.

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0, ## original 8 ## worker를 gpu에 할당하지 못하는 환경에선 0으로 셋팅
                        batch_size=8)

dataiter = iter(vis_dataloader)


example_batch = next(dataiter)
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# [[1.]
#  [1.]
#  [0.]
#  [1.]
#  [1.]
#  [0.]
#  [0.]
#  [1.]]

# %% [markdown]
# ## Neural Net Definition
# We will use a standard convolutional neural network

# %%
# class SiameseNetwork(nn.Module):
#     def __init__(self):
#         super(SiameseNetwork, self).__init__()
#         self.cnn1 = nn.Sequential(
#             nn.ReflectionPad2d(1),
#             nn.Conv2d(1, 4, kernel_size=3),
#             nn.ReLU(inplace=True),
#             nn.BatchNorm2d(4),
            
#             nn.ReflectionPad2d(1),
#             nn.Conv2d(4, 8, kernel_size=3),
#             nn.ReLU(inplace=True),
#             nn.BatchNorm2d(8),


#             nn.ReflectionPad2d(1),
#             nn.Conv2d(8, 8, kernel_size=3),
#             nn.ReLU(inplace=True),
#             nn.BatchNorm2d(8),
#         )

#         self.fc1 = nn.Sequential(
#             nn.Linear(8*100*100, 500),
#             nn.ReLU(inplace=True),

#             nn.Linear(500, 500),
#             nn.ReLU(inplace=True),

#             nn.Linear(500, 5))

#     def forward_once(self, x):
#         output = self.cnn1(x)
#         output = output.view(output.size()[0], -1)
#         output = self.fc1(output)
#         return output

#     def forward(self, input1, input2):
#         output1 = self.forward_once(input1)
#         output2 = self.forward_once(input2)
#         return output1, output2

class SiameseNetwork2(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.fc1 = nn.Sequential(
            nn.Linear(256*6*6, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5),
            
            nn.Linear(512, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %% [markdown]
# ## Contrastive Loss

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %% [markdown]
# ## Training Time!

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=0, ## original 8
                        batch_size=Config.train_batch_size)

# %%
# net = SiameseNetwork().cuda() ## original torch와 쿠다가 호환되지 않아 에러발생
net = SiameseNetwork()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1 , label = data
#         img0, img1 , label = img0.cuda(), img1.cuda() , label.cuda()
        
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# Epoch number 0
#  Current loss 1.8411662578582764
#
# Epoch number 1
#  Current loss 1.8268486261367798
#
# Epoch number 2
#  Current loss 2.223609447479248
#
# Epoch number 3
#  Current loss 2.506915330886841
#
# Epoch number 4
#  Current loss 1.4066672325134277
#
# Epoch number 5
#  Current loss 1.5170012712478638
#
# Epoch number 6
#  Current loss 1.3854246139526367
#
# Epoch number 7
#  Current loss 1.6154983043670654
#
# Epoch number 8
#  Current loss 1.8355262279510498
#
# Epoch number 9
#  Current loss 1.7869094610214233
#
# Epoch number 10
#  Current loss 1.852830171585083
#
# Epoch number 11
#  Current loss 1.475169062614441
#
# Epoch number 12
#  Current loss 1.4463266134262085
#
# Epoch number 13
#  Current loss 1.1718496084213257
#
# Epoch number 14
#  Current loss 1.38127601146698
#
# Epoch number 15
#  Current loss 1.3949908018112183
#
# Epoch number 16
#  Current loss 1.3329710960388184
#
# Epoch number 17
#  Current loss 1.5559722185134888
#
# Epoch number 18
#  Current loss 1.5369130373001099
#
# Epoch number 19
#  Current loss 1.526550531387329
#
# Epoch number 20
#  Current loss 1.3948835134506226
#
# Epoch number 21
#  Current loss 1.2380529642105103
#
# Epoch number 22
#  Current loss 1.0943193435668945
#
# Epoch number 23
#  Current loss 1.3389222621917725
#
# Epoch number 24
#  Current loss 1.391838550567627
#
# Epoch number 25
#  Current loss 1.182827353477478
#
# Epoch number 26
#  Current loss 1.2383253574371338
#
# Epoch number 27
#  Current loss 1.2564958333969116
#
# Epoch number 28
#  Current loss 1.1190836429595947
#
# Epoch number 29
#  Current loss 1.1945363283157349
#
# Epoch number 30
#  Current loss 1.3213610649108887
#
# Epoch number 31
#  Current loss 1.038603663444519
#
# Epoch number 32
#  Current loss 1.1481513977050781
#
# Epoch number 33
#  Current loss 1.018754243850708
#
# Epoch number 34
#  Current loss 1.1373211145401
#
# Epoch number 35
#  Current loss 0.9993399977684021
#
# Epoch number 36
#  Current loss 1.2077254056930542
#
# Epoch number 37
#  Current loss 1.29292893409729
#
# Epoch number 38
#  Current loss 1.1559230089187622
#
# Epoch number 39
#  Current loss 1.401005744934082
#
# Epoch number 40
#  Current loss 1.1233150959014893
#
# Epoch number 41
#  Current loss 1.533798336982727
#
# Epoch number 42
#  Current loss 1.2340413331985474
#
# Epoch number 43
#  Current loss 1.1398441791534424
#
# Epoch number 44
#  Current loss 1.1573518514633179
#
# Epoch number 45
#  Current loss 1.050815463066101
#
# Epoch number 46
#  Current loss 1.1570507287979126
#
# Epoch number 47
#  Current loss 0.9946416616439819
#
# Epoch number 48
#  Current loss 1.1458231210708618
#
# Epoch number 49
#  Current loss 0.9800332188606262
#
# Epoch number 50
#  Current loss 0.8655587434768677
#
# Epoch number 51
#  Current loss 0.9617944955825806
#
# Epoch number 52
#  Current loss 1.1079254150390625
#
# Epoch number 53
#  Current loss 1.0668565034866333
#
# Epoch number 54
#  Current loss 1.039509892463684
#
# Epoch number 55
#  Current loss 1.006442666053772
#
# Epoch number 56
#  Current loss 0.8668813109397888
#
# Epoch number 57
#  Current loss 0.8990699648857117
#
# Epoch number 58
#  Current loss 1.0016824007034302
#
# Epoch number 59
#  Current loss 0.9532103538513184
#
# Epoch number 60
#  Current loss 0.7982825040817261
#
# Epoch number 61
#  Current loss 0.9251809120178223
#
# Epoch number 62
#  Current loss 0.9841663241386414
#
# Epoch number 63
#  Current loss 1.1989998817443848
#
# Epoch number 64
#  Current loss 0.8021645545959473
#
# Epoch number 65
#  Current loss 0.7132818698883057
#
# Epoch number 66
#  Current loss 0.809317946434021
#
# Epoch number 67
#  Current loss 0.8074995279312134
#
# Epoch number 68
#  Current loss 0.7588774561882019
#
# Epoch number 69
#  Current loss 0.736877977848053
#
# Epoch number 70
#  Current loss 0.9599041938781738
#
# Epoch number 71
#  Current loss 0.8699221611022949
#
# Epoch number 72
#  Current loss 0.7259382009506226
#
# Epoch number 73
#  Current loss 0.811523973941803
#
# Epoch number 74
#  Current loss 0.8738106489181519
#
# Epoch number 75
#  Current loss 0.8793448209762573
#
# Epoch number 76
#  Current loss 0.7845541834831238
#
# Epoch number 77
#  Current loss 0.7644975781440735
#
# Epoch number 78
#  Current loss 0.8178525567054749
#
# Epoch number 79
#  Current loss 0.8193472623825073
#
# Epoch number 80
#  Current loss 0.5474954843521118
#
# Epoch number 81
#  Current loss 0.6774778366088867
#
# Epoch number 82
#  Current loss 0.6096194982528687
#
# Epoch number 83
#  Current loss 0.597142219543457
#
# Epoch number 84
#  Current loss 0.6162224411964417
#
# Epoch number 85
#  Current loss 0.6029872894287109
#
# Epoch number 86
#  Current loss 0.7626863718032837
#
# Epoch number 87
#  Current loss 0.7578042149543762
#
# Epoch number 88
#  Current loss 0.7661207914352417
#
# Epoch number 89
#  Current loss 0.6957967877388
#
# Epoch number 90
#  Current loss 0.5047481656074524
#
# Epoch number 91
#  Current loss 0.5537455677986145
#
# Epoch number 92
#  Current loss 0.638556718826294
#
# Epoch number 93
#  Current loss 0.5213569402694702
#
# Epoch number 94
#  Current loss 0.5354017019271851
#
# Epoch number 95
#  Current loss 0.46641844511032104
#
# Epoch number 96
#  Current loss 0.4930585026741028
#
# Epoch number 97
#  Current loss 0.5908687114715576
#
# Epoch number 98
#  Current loss 0.5873000025749207
#
# Epoch number 99
#  Current loss 0.41614270210266113
#
# Epoch number 100
#  Current loss 0.6100478172302246
#
# Epoch number 101
#  Current loss 0.3984074294567108
#
# Epoch number 102
#  Current loss 0.4996723532676697
#
# Epoch number 103
#  Current loss 0.504136860370636
#
# Epoch number 104
#  Current loss 0.32003459334373474
#
# Epoch number 105
#  Current loss 0.5465365052223206
#
# Epoch number 106
#  Current loss 0.4562563896179199
#
# Epoch number 107
#  Current loss 0.4972090423107147
#
# Epoch number 108
#  Current loss 0.42695969343185425
#
# Epoch number 109
#  Current loss 0.509190559387207
#
# Epoch number 110
#  Current loss 0.5162431001663208
#
# Epoch number 111
#  Current loss 0.4293004274368286
#
# Epoch number 112
#  Current loss 0.3576207160949707
#
# Epoch number 113
#  Current loss 0.5068444013595581
#
# Epoch number 114
#  Current loss 0.379218727350235
#
# Epoch number 115
#  Current loss 0.5445404648780823
#
# Epoch number 116
#  Current loss 0.2904684245586395
#
# Epoch number 117
#  Current loss 0.387493759393692
#
# Epoch number 118
#  Current loss 0.49488958716392517
#
# Epoch number 119
#  Current loss 0.4042857885360718
#
# Epoch number 120
#  Current loss 0.38365188241004944
#
# Epoch number 121
#  Current loss 0.4499133229255676
#
# Epoch number 122
#  Current loss 0.3037862777709961
#
# Epoch number 123
#  Current loss 0.34109774231910706
#
# Epoch number 124
#  Current loss 0.28923678398132324
#
# Epoch number 125
#  Current loss 0.2932896614074707
#
# Epoch number 126
#  Current loss 0.28718194365501404
#
# Epoch number 127
#  Current loss 0.3626195788383484
#
# Epoch number 128
#  Current loss 0.3193165063858032
#
# Epoch number 129
#  Current loss 0.344105988740921
#
# Epoch number 130
#  Current loss 0.29409632086753845
#
# Epoch number 131
#  Current loss 0.4289515018463135
#
# Epoch number 132
#  Current loss 0.28029248118400574
#
# Epoch number 133
#  Current loss 0.352041631937027
#
# Epoch number 134
#  Current loss 0.32182449102401733
#
# Epoch number 135
#  Current loss 0.2430000901222229
#
# Epoch number 136
#  Current loss 0.3140794038772583
#
# Epoch number 137
#  Current loss 0.27421051263809204
#
# Epoch number 138
#  Current loss 0.3178640902042389
#
# Epoch number 139
#  Current loss 0.37403565645217896
#
# Epoch number 140
#  Current loss 0.24205051362514496
#
# Epoch number 141
#  Current loss 0.33691197633743286
#
# Epoch number 142
#  Current loss 0.32027116417884827
#
# Epoch number 143
#  Current loss 0.228123277425766
#
# Epoch number 144
#  Current loss 0.32882481813430786
#
# Epoch number 145
#  Current loss 0.17154866456985474
#
# Epoch number 146
#  Current loss 0.2262381911277771
#
# Epoch number 147
#  Current loss 0.22100628912448883
#
# Epoch number 148
#  Current loss 0.2388162463903427
#
# Epoch number 149
#  Current loss 0.31078895926475525
#
# Epoch number 150
#  Current loss 0.3147079646587372
#
# Epoch number 151
#  Current loss 0.22517766058444977
#
# Epoch number 152
#  Current loss 0.2391124665737152
#
# Epoch number 153
#  Current loss 0.2336205542087555
#
# Epoch number 154
#  Current loss 0.2834908664226532
#
# Epoch number 155
#  Current loss 0.36660337448120117
#
# Epoch number 156
#  Current loss 0.30603453516960144
#
# Epoch number 157
#  Current loss 0.19949977099895477
#
# Epoch number 158
#  Current loss 0.23079700767993927
#
# Epoch number 159
#  Current loss 0.2006722241640091
#
# Epoch number 160
#  Current loss 0.22893670201301575
#
# Epoch number 161
#  Current loss 0.23296396434307098
#
# Epoch number 162
#  Current loss 0.20726026594638824
#
# Epoch number 163
#  Current loss 0.21263952553272247
#
# Epoch number 164
#  Current loss 0.22180604934692383
#
# Epoch number 165
#  Current loss 0.31389880180358887
#
# Epoch number 166
#  Current loss 0.2095744013786316
#
# Epoch number 167
#  Current loss 0.24403321743011475
#
# Epoch number 168
#  Current loss 0.28812432289123535
#
# Epoch number 169
#  Current loss 0.2637028694152832
#
# Epoch number 170
#  Current loss 0.22836121916770935
#
# Epoch number 171
#  Current loss 0.19373644888401031
#
# Epoch number 172
#  Current loss 0.21641193330287933
#
# Epoch number 173
#  Current loss 0.2209307998418808
#
# Epoch number 174
#  Current loss 0.2281043529510498
#
# Epoch number 175
#  Current loss 0.18393991887569427
#
# Epoch number 176
#  Current loss 0.21097753942012787
#
# Epoch number 177
#  Current loss 0.1772659868001938
#
# Epoch number 178
#  Current loss 0.22110824286937714
#
# Epoch number 179
#  Current loss 0.1641475409269333
#
# Epoch number 180
#  Current loss 0.23077386617660522
#
# Epoch number 181
#  Current loss 0.1938159465789795
#
# Epoch number 182
#  Current loss 0.17889128625392914
#
# Epoch number 183
#  Current loss 0.16006144881248474
#
# Epoch number 184
#  Current loss 0.17643088102340698
#
# Epoch number 185
#  Current loss 0.12168379873037338
#
# Epoch number 186
#  Current loss 0.19552436470985413
#
# Epoch number 187
#  Current loss 0.19662487506866455
#
# Epoch number 188
#  Current loss 0.1319991946220398
#
# Epoch number 189
#  Current loss 0.18143266439437866
#
# Epoch number 190
#  Current loss 0.16235145926475525
#
# Epoch number 191
#  Current loss 0.14670629799365997
#
# Epoch number 192
#  Current loss 0.12471318244934082
#
# Epoch number 193
#  Current loss 0.1931449919939041
#
# Epoch number 194
#  Current loss 0.14731533825397491
#
# Epoch number 195
#  Current loss 0.11394456028938293
#
# Epoch number 196
#  Current loss 0.19387683272361755
#
# Epoch number 197
#  Current loss 0.16589204967021942
#
# Epoch number 198
#  Current loss 0.17429247498512268
#
# Epoch number 199
#  Current loss 0.1593950390815735
#
# Epoch number 200
#  Current loss 0.17542065680027008
#
# Epoch number 201
#  Current loss 0.1464240700006485
#
# Epoch number 202
#  Current loss 0.1412985920906067
#
# Epoch number 203
#  Current loss 0.16370119154453278
#
# Epoch number 204
#  Current loss 0.13331915438175201
#
# Epoch number 205
#  Current loss 0.12839365005493164
#
# Epoch number 206
#  Current loss 0.16898132860660553
#
# Epoch number 207
#  Current loss 0.12663783133029938
#
# Epoch number 208
#  Current loss 0.13447469472885132
#
# Epoch number 209
#  Current loss 0.15226233005523682
#
# Epoch number 210
#  Current loss 0.11533733457326889
#
# Epoch number 211
#  Current loss 0.20664852857589722
#
# Epoch number 212
#  Current loss 0.15210068225860596
#
# Epoch number 213
#  Current loss 0.16455893218517303
#
# Epoch number 214
#  Current loss 0.14954030513763428
#
# Epoch number 215
#  Current loss 0.17914694547653198
#
# Epoch number 216
#  Current loss 0.18746070563793182
#
# Epoch number 217
#  Current loss 0.11100280284881592
#
# Epoch number 218
#  Current loss 0.13477663695812225
#
# Epoch number 219
#  Current loss 0.1598857194185257
#
# Epoch number 220
#  Current loss 0.14742715656757355
#
# Epoch number 221
#  Current loss 0.2274373471736908
#
# Epoch number 222
#  Current loss 0.12819702923297882
#
# Epoch number 223
#  Current loss 0.14321017265319824
#
# Epoch number 224
#  Current loss 0.110344797372818
#
# Epoch number 225
#  Current loss 0.09580709040164948
#
# Epoch number 226
#  Current loss 0.1186881884932518
#
# Epoch number 227
#  Current loss 0.08932452648878098
#
# Epoch number 228
#  Current loss 0.13559338450431824
#
# Epoch number 229
#  Current loss 0.09809383004903793
#
# Epoch number 230
#  Current loss 0.13804686069488525
#
# Epoch number 231
#  Current loss 0.14174114167690277
#
# Epoch number 232
#  Current loss 0.10913418233394623
#
# Epoch number 233
#  Current loss 0.12503434717655182
#
# Epoch number 234
#  Current loss 0.13053026795387268
#
# Epoch number 235
#  Current loss 0.10399777442216873
#
# Epoch number 236
#  Current loss 0.11901409178972244
#
# Epoch number 237
#  Current loss 0.1362868845462799
#
# Epoch number 238
#  Current loss 0.0919632613658905
#
# Epoch number 239
#  Current loss 0.0961640477180481
#
# Epoch number 240
#  Current loss 0.10910838842391968
#
# Epoch number 241
#  Current loss 0.12426923215389252
#
# Epoch number 242
#  Current loss 0.1445918083190918
#
# Epoch number 243
#  Current loss 0.13875193893909454
#
# Epoch number 244
#  Current loss 0.1492704153060913
#
# Epoch number 245
#  Current loss 0.12012075632810593
#
# Epoch number 246
#  Current loss 0.12097886949777603
#
# Epoch number 247
#  Current loss 0.10475948452949524
#
# Epoch number 248
#  Current loss 0.10749794542789459
#
# Epoch number 249
#  Current loss 0.1151748076081276
#
# Epoch number 250
#  Current loss 0.11678101867437363
#
# Epoch number 251
#  Current loss 0.11970442533493042
#
# Epoch number 252
#  Current loss 0.1550845354795456
#
# Epoch number 253
#  Current loss 0.08991453051567078
#
# Epoch number 254
#  Current loss 0.09929724037647247
#
# Epoch number 255
#  Current loss 0.09473153948783875
#
# Epoch number 256
#  Current loss 0.1400657594203949
#
# Epoch number 257
#  Current loss 0.11105870455503464
#
# Epoch number 258
#  Current loss 0.10278694331645966
#
# Epoch number 259
#  Current loss 0.11848080158233643
#
# Epoch number 260
#  Current loss 0.1287076473236084
#
# Epoch number 261
#  Current loss 0.1616072803735733
#
# Epoch number 262
#  Current loss 0.12655988335609436
#
# Epoch number 263
#  Current loss 0.09638082981109619
#
# Epoch number 264
#  Current loss 0.10980343818664551
#
# Epoch number 265
#  Current loss 0.12083722651004791
#
# Epoch number 266
#  Current loss 0.09100314229726791
#
# Epoch number 267
#  Current loss 0.11016187816858292
#
# Epoch number 268
#  Current loss 0.09157659858465195
#
# Epoch number 269
#  Current loss 0.09773688018321991
#
# Epoch number 270
#  Current loss 0.09149398654699326
#
# Epoch number 271
#  Current loss 0.10079607367515564
#
# Epoch number 272
#  Current loss 0.10739678889513016
#
# Epoch number 273
#  Current loss 0.11225855350494385
#
# Epoch number 274
#  Current loss 0.16903230547904968
#
# Epoch number 275
#  Current loss 0.07023037225008011
#
# Epoch number 276
#  Current loss 0.11084354668855667
#
# Epoch number 277
#  Current loss 0.09371878951787949
#
# Epoch number 278
#  Current loss 0.16990958154201508
#
# Epoch number 279
#  Current loss 0.0993698388338089
#
# Epoch number 280
#  Current loss 0.15992039442062378
#
# Epoch number 281
#  Current loss 0.08375368267297745
#
# Epoch number 282
#  Current loss 0.09712380915880203
#
# Epoch number 283
#  Current loss 0.15351223945617676
#
# Epoch number 284
#  Current loss 0.10888999700546265
#
# Epoch number 285
#  Current loss 0.09734606742858887
#
# Epoch number 286
#  Current loss 0.1402687132358551
#
# Epoch number 287
#  Current loss 0.12377597391605377
#
# Epoch number 288
#  Current loss 0.09192082285881042
#
# Epoch number 289
#  Current loss 0.09902463108301163
#
# Epoch number 290
#  Current loss 0.10225528478622437
#
# Epoch number 291
#  Current loss 0.1090352013707161
#
# Epoch number 292
#  Current loss 0.08529456704854965
#
# Epoch number 293
#  Current loss 0.1500149667263031
#
# Epoch number 294
#  Current loss 0.07991732656955719
#
# Epoch number 295
#  Current loss 0.10659899562597275
#
# Epoch number 296
#  Current loss 0.10035759210586548
#
# Epoch number 297
#  Current loss 0.11812638491392136
#
# Epoch number 298
#  Current loss 0.11872071027755737
#
# Epoch number 299
#  Current loss 0.1019156202673912
#
# Epoch number 300
#  Current loss 0.11050905287265778
#
# Epoch number 301
#  Current loss 0.1623142510652542
#
# Epoch number 302
#  Current loss 0.11497893929481506
#
# Epoch number 303
#  Current loss 0.09209389984607697
#
# Epoch number 304
#  Current loss 0.08915438503026962
#
# Epoch number 305
#  Current loss 0.10102803260087967
#
# Epoch number 306
#  Current loss 0.07563916593790054
#
# Epoch number 307
#  Current loss 0.14291538298130035
#
# Epoch number 308
#  Current loss 0.09099049121141434
#
# Epoch number 309
#  Current loss 0.10739357769489288
#
# Epoch number 310
#  Current loss 0.08220160007476807
#
# Epoch number 311
#  Current loss 0.0952099934220314
#
# Epoch number 312
#  Current loss 0.1306888908147812
#
# Epoch number 313
#  Current loss 0.10812947154045105
#
# Epoch number 314
#  Current loss 0.1032637506723404
#
# Epoch number 315
#  Current loss 0.09285913407802582
#
# Epoch number 316
#  Current loss 0.09842392802238464
#
# Epoch number 317
#  Current loss 0.08683917671442032
#
# Epoch number 318
#  Current loss 0.10610197484493256
#
# Epoch number 319
#  Current loss 0.13964420557022095
#
# Epoch number 320
#  Current loss 0.07818697392940521
#
# Epoch number 321
#  Current loss 0.17438577115535736
#
# Epoch number 322
#  Current loss 0.06924186646938324
#
# Epoch number 323
#  Current loss 0.07146944850683212
#
# Epoch number 324
#  Current loss 0.08025670051574707
#
# Epoch number 325
#  Current loss 0.11206796020269394
#
# Epoch number 326
#  Current loss 0.11257636547088623
#
# Epoch number 327
#  Current loss 0.1233319565653801
#
# Epoch number 328
#  Current loss 0.08185230940580368
#
# Epoch number 329
#  Current loss 0.08195845037698746
#
# Epoch number 330
#  Current loss 0.11211077868938446
#
# Epoch number 331
#  Current loss 0.07531975209712982
#
# Epoch number 332
#  Current loss 0.08234304189682007
#
# Epoch number 333
#  Current loss 0.09998612105846405
#
# Epoch number 334
#  Current loss 0.09964915364980698
#
# Epoch number 335
#  Current loss 0.0606556199491024
#
# Epoch number 336
#  Current loss 0.09158201515674591
#
# Epoch number 337
#  Current loss 0.07036653161048889
#
# Epoch number 338
#  Current loss 0.1192399337887764
#
# Epoch number 339
#  Current loss 0.09039749205112457
#
# Epoch number 340
#  Current loss 0.12137497961521149
#
# Epoch number 341
#  Current loss 0.06591583788394928
#
# Epoch number 342
#  Current loss 0.11960327625274658
#
# Epoch number 343
#  Current loss 0.09723947942256927
#
# Epoch number 344
#  Current loss 0.05864982679486275
#
# Epoch number 345
#  Current loss 0.06594349443912506
#
# Epoch number 346
#  Current loss 0.1033383160829544
#
# Epoch number 347
#  Current loss 0.07820151746273041
#
# Epoch number 348
#  Current loss 0.06578938663005829
#
# Epoch number 349
#  Current loss 0.11885794252157211
#
# Epoch number 350
#  Current loss 0.060961976647377014
#
# Epoch number 351
#  Current loss 0.10892660915851593
#
# Epoch number 352
#  Current loss 0.09744216501712799
#
# Epoch number 353
#  Current loss 0.10057059675455093
#
# Epoch number 354
#  Current loss 0.08084908872842789
#
# Epoch number 355
#  Current loss 0.08381745219230652
#
# Epoch number 356
#  Current loss 0.08644863963127136
#
# Epoch number 357
#  Current loss 0.06024662405252457
#
# Epoch number 358
#  Current loss 0.06230289861559868
#
# Epoch number 359
#  Current loss 0.09173980355262756
#
# Epoch number 360
#  Current loss 0.10219189524650574
#
# Epoch number 361
#  Current loss 0.0922132134437561
#
# Epoch number 362
#  Current loss 0.08204303681850433
#
# Epoch number 363
#  Current loss 0.059621840715408325
#
# Epoch number 364
#  Current loss 0.055545344948768616
#
# Epoch number 365
#  Current loss 0.0809260904788971
#
# Epoch number 366
#  Current loss 0.08367091417312622
#
# Epoch number 367
#  Current loss 0.08494475483894348
#
# Epoch number 368
#  Current loss 0.08213453739881516
#
# Epoch number 369
#  Current loss 0.08037015050649643
#
# Epoch number 370
#  Current loss 0.07395646721124649
#
# Epoch number 371
#  Current loss 0.056106679141521454
#
# Epoch number 372
#  Current loss 0.08979502320289612
#
# Epoch number 373
#  Current loss 0.06730469316244125
#
# Epoch number 374
#  Current loss 0.0642625018954277
#
# Epoch number 375
#  Current loss 0.05367144197225571
#
# Epoch number 376
#  Current loss 0.047491349279880524
#
# Epoch number 377
#  Current loss 0.0807996466755867
#
# Epoch number 378
#  Current loss 0.1142844557762146
#
# Epoch number 379
#  Current loss 0.06939971446990967
#
# Epoch number 380
#  Current loss 0.08158691972494125
#
# Epoch number 381
#  Current loss 0.08779068291187286
#
# Epoch number 382
#  Current loss 0.09133592247962952
#
# Epoch number 383
#  Current loss 0.06982918083667755
#
# Epoch number 384
#  Current loss 0.07140254229307175
#
# Epoch number 385
#  Current loss 0.05750870332121849
#
# Epoch number 386
#  Current loss 0.06403907388448715
#
# Epoch number 387
#  Current loss 0.07142549008131027
#
# Epoch number 388
#  Current loss 0.071689672768116
#
# Epoch number 389
#  Current loss 0.05867701768875122
#
# Epoch number 390
#  Current loss 0.06827539950609207
#
# Epoch number 391
#  Current loss 0.08872880041599274
#
# Epoch number 392
#  Current loss 0.06233026832342148
#
# Epoch number 393
#  Current loss 0.08420784771442413
#
# Epoch number 394
#  Current loss 0.09250576794147491
#
# Epoch number 395
#  Current loss 0.06672713905572891
#
# Epoch number 396
#  Current loss 0.07131548225879669
#
# Epoch number 397
#  Current loss 0.06295400112867355
#
# Epoch number 398
#  Current loss 0.05737968161702156
#
# Epoch number 399
#  Current loss 0.055803850293159485

# %%
# model_scripted = torch.jit.script(net) # TorchScript 형식으로 내보내기
# model_scripted.save('/content/drive/My Drive/Colab Notebooks/model/model_scripted_epoch100_batch_64.pt')

torch.save(net.state_dict(), "/content/drive/My Drive/Colab Notebooks/model/model_epoch"+str(Config.train_number_epochs)+"_batch_"+str(Config.train_batch_size)+"_5in_20_bright_ver2.pt")

# %%
device = torch.device('cpu')
net.load_state_dict(torch.load("/content/drive/My Drive/Colab Notebooks/model/model_epoch"+str(Config.train_number_epochs)+"_batch_"+str(Config.train_batch_size)+"_5in_20_bright_ver2.pt", map_location=device))
# net.load_state_dict(torch.load("/content/drive/My Drive/Colab Notebooks/model/model_epoch100_batch_64_KETI3.pt", map_location=device))
net.eval()

# device = torch.device("cuda")
# net.load_state_dict(torch.load("/content/drive/My Drive/Colab Notebooks/model/model_epoch"+str(train_number_epochs)+"_batch_"+str(train_batch_size)+".pt", map_location="cuda:0"))  # 사용할 GPU 장치 번호를 선택합니다.
# net.to(device)
# net.eval()
# Out:
# SiameseNetwork(
#   (cnn1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace=True)
#     (24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc1): Sequential(
#     (0): Linear(in_features=9216, out_features=1024, bias=True)
#     (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %% [markdown]
# ## Some simple testing
# The last 3 subjects were held out from the training, and will be used to test. The Distance between each image pair denotes the degree of similarity the model found between the two images. Less means it found more similar, while higher values indicate it found them to be dissimilar.

# %%
# test_dir = "/content/drive/My Drive/Colab Notebooks/data/5in_20_bright_ver2/testing2"
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
# folder_dataset_test = dset.ImageFolder(root=test_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

test_dataloader = DataLoader(siamese_dataset,num_workers=0,batch_size=1,shuffle=True) ## original.. num_workers = 6
dataiter = iter(test_dataloader)
x0,_,_ = next(dataiter)

for i in range(10):
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)
    output1,output2 = net(Variable(x0),Variable(x1))
#     output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))

# %%
# test_dir = "/content/drive/My Drive/Colab Notebooks/data/2in_10_same_angle/testing"
# # folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)
# folder_dataset_test = dset.ImageFolder(root=test_dir)
# siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset_test,
#                                         transform=transforms.Compose([transforms.Resize((100,100)),
#                                                                       transforms.ToTensor()
#                                                                       ])
#                                        ,should_invert=False)

# test_dataloader = DataLoader(siamese_dataset,num_workers=0,batch_size=1,shuffle=True) ## original.. num_workers = 6
# dataiter = iter(test_dataloader)
# x0,_,_ = next(dataiter)

# for i in range(10):
#     _,x1,label2 = next(dataiter)
#     concatenated = torch.cat((x0,x1),0)
#     output1,output2 = net(Variable(x0),Variable(x1))
# #     output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
#     euclidean_distance = F.pairwise_distance(output1, output2)
#     imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
